# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np

# %%
county_data = pd.read_csv('Downloads/HRI_Data (2).csv')
print(county_data.head())
# Out:
#          Area  counts2017  counts2018  counts2019  counts2020  counts2021  \
# 0    Accomack         2.0         2.0        13.0        18.0        26.0
# 1   Albemarle        42.0        45.0        47.0        17.0        29.0
# 2  Alexandria        13.0        15.0        21.0        11.0        16.0
# 3   Alleghany         6.0        10.0         8.0        15.0         7.0
# 4      Amelia         2.0         2.0         8.0         5.0         2.0
#
#   sum2017 sum2018 sum2019 sum2020  ... Median_2021_BlackorAfricanAmerican  \
# 0   32685   32581   32316   33392  ...                            39059.0
# 1  155231  108377  109330  112510  ...                            63045.0
# 2  159215  159069  159428  159139  ...                            27257.0
# 3   20704    5578    5538    5745  ...                            68969.0
# 4   12980   13057   13145   13267  ...                            44416.0
#
# ...

# %%
formula = "hri2017 ~ Medianincome_2017_45to64years"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2017   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          37.745
# Method:                          IRLS   Log-Likelihood:                -348.30
# Date:                Tue, 28 Jan 2025   Deviance:                       4000.9
# Time:                        19:24:17   Pearson chi2:                 4.00e+03
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.003247
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
county_data['predicted_HRI_rate'] = glm_result.predict()
plt.scatter(county_data['predicted_HRI_rate'], county_data['hri2019'])
plt.xlabel("Predicted HRI Rate")
plt.ylabel("Actual HRI Rate")
plt.title("Predicted vs. Actual HRI Rates")
plt.show()

# %%
formula = "hri2017 ~ Medianincome_2017_65yearsandover"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2017   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          37.740
# Method:                          IRLS   Log-Likelihood:                -348.29
# Date:                Tue, 28 Jan 2025   Deviance:                       4000.4
# Time:                        19:26:12   Pearson chi2:                 4.00e+03
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.003374
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2017 ~ Medianincome_2017_Families"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2017   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          37.597
# Method:                          IRLS   Log-Likelihood:                -348.09
# Date:                Tue, 28 Jan 2025   Deviance:                       3985.3
# Time:                        19:26:24   Pearson chi2:                 3.99e+03
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.007092
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2017 ~ Medianincome_2017_45to64years"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2017   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          37.745
# Method:                          IRLS   Log-Likelihood:                -348.30
# Date:                Tue, 28 Jan 2025   Deviance:                       4000.9
# Time:                        19:26:25   Pearson chi2:                 4.00e+03
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.003247
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2018 ~ Median_2018_Households"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2018   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          98.740
# Method:                          IRLS   Log-Likelihood:                -400.23
# Date:                Tue, 28 Jan 2025   Deviance:                       10466.
# Time:                        19:27:32   Pearson chi2:                 1.05e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.01623
# Covariance Type:            nonrobust
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2018 ~ Median_2018_White"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2018   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          100.01
# Method:                          IRLS   Log-Likelihood:                -400.92
# Date:                Tue, 28 Jan 2025   Deviance:                       10601.
# Time:                        19:27:36   Pearson chi2:                 1.06e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.003652
# Covariance Type:            nonrobust
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2018 ~ Median_2018_BlackorAfricanAmerican"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2018   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          99.328
# Method:                          IRLS   Log-Likelihood:                -400.55
# Date:                Tue, 28 Jan 2025   Deviance:                       10529.
# Time:                        19:27:39   Pearson chi2:                 1.05e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.01040
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2018 ~ Median_2018_45to64years"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2018   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          98.380
# Method:                          IRLS   Log-Likelihood:                -400.03
# Date:                Tue, 28 Jan 2025   Deviance:                       10428.
# Time:                        19:27:43   Pearson chi2:                 1.04e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.01981
# Covariance Type:            nonrobust
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2018 ~ Median_2018_65yearsandover"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2018   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          99.101
# Method:                          IRLS   Log-Likelihood:                -400.43
# Date:                Tue, 28 Jan 2025   Deviance:                       10505.
# Time:                        19:27:46   Pearson chi2:                 1.05e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.01264
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2018 ~ Median_2018_Families"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2018   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          98.916
# Method:                          IRLS   Log-Likelihood:                -400.33
# Date:                Tue, 28 Jan 2025   Deviance:                       10485.
# Time:                        19:28:02   Pearson chi2:                 1.05e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.01448
# Covariance Type:            nonrobust
# ...
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2019 ~ Median_2019_Households"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2019   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          143.89
# Method:                          IRLS   Log-Likelihood:                -420.57
# Date:                Tue, 28 Jan 2025   Deviance:                       15253.
# Time:                        19:29:02   Pearson chi2:                 1.53e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.02603
# Covariance Type:            nonrobust
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2019 ~ Median_2019_White"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2019   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          146.63
# Method:                          IRLS   Log-Likelihood:                -421.58
# Date:                Tue, 28 Jan 2025   Deviance:                       15542.
# Time:                        19:29:20   Pearson chi2:                 1.55e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.007573
# Covariance Type:            nonrobust
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2019 ~ Median_2019_BlackorAfricanAmerican"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2019   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          146.96
# Method:                          IRLS   Log-Likelihood:                -421.70
# Date:                Tue, 28 Jan 2025   Deviance:                       15577.
# Time:                        19:29:48   Pearson chi2:                 1.56e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.005376
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
formula = "hri2019 ~ Median_2019_45to64years"
glm = smf.glm(formula=formula, data=county_data, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                hri2019   No. Observations:                  108
# Model:                            GLM   Df Residuals:                      106
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                          143.41
# Method:                          IRLS   Log-Likelihood:                -420.39
# Date:                Tue, 28 Jan 2025   Deviance:                       15202.
# Time:                        19:30:18   Pearson chi2:                 1.52e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.02933
# Covariance Type:            nonrobust
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.formula.api import ols
county_data['log_hri'] = np.log(county_data['hri2017'] + 1)  # Add 1 to avoid log(0)

# Run regression
formula = "log_hri ~ Medianincome_2017_45to64years"
model = ols(formula, data=county_data).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                log_hri   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                  0.001503
# Date:                Tue, 28 Jan 2025   Prob (F-statistic):              0.969
# Time:                        19:48:20   Log-Likelihood:                -90.189
# No. Observations:                 108   AIC:                             184.4
# Df Residuals:                     106   BIC:                             189.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         1.0465      0.166      6.322      0.000       0.718       1.375
# ...

# %%
county_data['log_income'] = np.log(county_data['Medianincome_2017_45to64years'])

formula = "hri2017 ~ log_income"
model = ols(formula, data=county_data).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                hri2017   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.2558
# Date:                Tue, 28 Jan 2025   Prob (F-statistic):              0.614
# Time:                        19:49:39   Log-Likelihood:                -348.34
# No. Observations:                 108   AIC:                             700.7
# Df Residuals:                     106   BIC:                             706.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.9378     20.326      0.637      0.526     -27.360      53.236
# ...

# %%
merged_data = census_block_data.merge(county_data, on="CNTY_NAME", how="inner")

# %%
merged_data.head()
# Out:
#    BlockGroup_ID                    CNTY_NAME  ACSTOTPOP   Total m2  \
# 0   5.119101e+11  Abingdon, Washington County     1478.0   766532.0
# 1   5.119101e+11  Abingdon, Washington County     1270.0   114980.0
# 2   5.119101e+11  Abingdon, Washington County     3040.0  2245563.0
# 3   5.119101e+11  Abingdon, Washington County     1291.0  2061261.0
# 4   5.119101e+11  Abingdon, Washington County     1641.0  1730033.0
#
#    PEOPCOLORPCT  LOWINCPCT  UNEMPPCT  LINGISOPCT  LESSHSPCT  LIFEEXPPCT  ...  \
# 0      0.085250   0.144790  0.094840    0.000000   0.079930    0.172308  ...
# 1      0.034646   0.073228  0.000000    0.000000   0.053302    0.172308  ...
# 2      0.033882   0.281104  0.104282    0.002770   0.133694    0.213333  ...
# 3      0.034082   0.179706  0.096154    0.015411   0.046296    0.225641  ...
# 4      0.084095   0.261568  0.028916    0.000000   0.082333    0.225641  ...
#
#    PCT_ImpSurf  MeanTemp_F  zMeanTemp_F  Unnamed: 14  2017 calc  2018 calc  \
# ...

# %%
merged_data = merged_data.drop(columns=["Unnamed: 14"])

# %%
mean = merged_data['MeanTemp_F'].mean()
std_dev = merged_data['MeanTemp_F'].std()

# %%
print(mean)
print(std_dev)
# Out:
# 90.62671798111504
# 1.6157680057719472

# %%
percentile_threshold = merged_data['MeanTemp_F'].quantile(0.95)  # Top 5%
merged_data['High_Heat_Block'] = merged_data['MeanTemp_F'] > percentile_threshold
print(percentile_threshold)
# Out:
# 92.7112018295

# %%
merged_data['High_Heat_Block'] = merged_data['MeanTemp_F'] > percentile_threshold

# %%
sns.histplot(merged_data['MeanTemp_F'], kde=True)
plt.axvline(percentile_threshold, color='red', linestyle='--', label='Outlier Threshold')
plt.legend()
plt.show()

# %%
high_heat_data = merged_data[merged_data['High_Heat_Block']]

print(high_heat_data.describe())

print(high_heat_data['CNTY_NAME'].value_counts())
# Out:
#        BlockGroup_ID    ACSTOTPOP      Total m2  PEOPCOLORPCT  LOWINCPCT  \
# count   4.300000e+01    43.000000  4.300000e+01     43.000000  43.000000
# mean    5.144308e+11  1058.418605  4.432151e+05      0.361101   0.242349
# std     4.062799e+09   478.355876  6.323425e+05      0.219014   0.226810
# min     5.101310e+11     0.000000  2.676200e+04      0.000000   0.000000
# 25%     5.101310e+11   749.000000  8.536100e+04      0.217478   0.074153
# 50%     5.176003e+11  1066.000000  2.480020e+05      0.329374   0.162698
# 75%     5.184000e+11  1346.000000  4.414200e+05      0.469229   0.353538
# max     5.184000e+11  2230.000000  3.428147e+06      0.897233   0.953307
#
#         UNEMPPCT  LINGISOPCT  LESSHSPCT  LIFEEXPPCT  Pct_Trees  PCT_ImpSurf  \
# count  43.000000   43.000000  43.000000   43.000000  43.000000    43.000000
# mean    0.028037    0.031804   0.071190    0.148145   0.075200     0.687152
# std     0.040348    0.061905   0.093709    0.080040   0.052626     0.189727
# ...

# %%
print(merged_data.describe())
# Out:
#        BlockGroup_ID    ACSTOTPOP      Total m2  PEOPCOLORPCT   LOWINCPCT  \
# count   8.520000e+02   852.000000  8.520000e+02    852.000000  852.000000
# mean    5.157716e+11  1258.377934  9.467542e+05      0.430442    0.266780
# std     3.307144e+09   584.233468  1.218017e+06      0.269881    0.214450
# min     5.101310e+11     0.000000  1.466300e+04      0.000000    0.000000
# 25%     5.119101e+11   839.750000  2.950012e+05      0.201000    0.101353
# 50%     5.176004e+11  1185.500000  5.407640e+05      0.396510    0.203780
# 75%     5.181004e+11  1565.500000  1.125576e+06      0.636826    0.398637
# max     5.184000e+11  5104.000000  1.426184e+07      1.000000    1.000000
#
#          UNEMPPCT  LINGISOPCT   LESSHSPCT  LIFEEXPPCT   Pct_Trees  \
# count  852.000000  852.000000  852.000000  852.000000  852.000000
# mean     0.047737    0.027982    0.085315    0.170779    0.213061
# std      0.062675    0.061178    0.103318    0.081127    0.159636
# ...

# %%
#grouping instead of outliers
bins = [83, 86, 89, 92, 95]  
labels = ['83-86°F', '86-89°F', '89-92°F', '92-95°F']

merged_data['Temp_Band'] = pd.cut(merged_data['MeanTemp_F'], bins=bins, labels=labels, right=False)

illness_by_band = merged_data.groupby('Temp_Band')['avg_calc'].sum()
print(illness_by_band)
observed=True
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Temp_Band
# 83-86°F       54.203922
# 86-89°F      250.308890
# 89-92°F    18427.187875
# 92-95°F     2014.730610
# Name: avg_calc, dtype: float64
# /var/folders/b0/lgsgl68j49n3gcwkd6ppg8xc0000gn/T/ipykernel_11864/4233484528.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   illness_by_band = merged_data.groupby('Temp_Band')['avg_calc'].sum()

# %%
print(merged_data[merged_data['Temp_Band'] == '92–95°F'])
# Out:
# Empty DataFrame
# Columns: [BlockGroup_ID, CNTY_NAME, ACSTOTPOP, Total m2, PEOPCOLORPCT, LOWINCPCT, UNEMPPCT, LINGISOPCT, LESSHSPCT, LIFEEXPPCT, Pct_Trees, PCT_ImpSurf, MeanTemp_F, zMeanTemp_F, 2017 calc, 2018 calc, 2019 calc, 2020 calc, 2021 calc, avg_calc, High_Heat_Block, Temp_Band]
# Index: []
#
# [0 rows x 22 columns]

# %%
print(merged_data[
    (merged_data['MeanTemp_F'] == 83) |
    (merged_data['MeanTemp_F'] == 86) |
    (merged_data['MeanTemp_F'] == 89) |
    (merged_data['MeanTemp_F'] == 92) |
    (merged_data['MeanTemp_F'] == 95)
])
# Out:
# Empty DataFrame
# Columns: [BlockGroup_ID, CNTY_NAME, ACSTOTPOP, Total m2, PEOPCOLORPCT, LOWINCPCT, UNEMPPCT, LINGISOPCT, LESSHSPCT, LIFEEXPPCT, Pct_Trees, PCT_ImpSurf, MeanTemp_F, zMeanTemp_F, 2017 calc, 2018 calc, 2019 calc, 2020 calc, 2021 calc, avg_calc, High_Heat_Block, Temp_Band]
# Index: []
#
# [0 rows x 22 columns]

# %%
X = merged_data['MeanTemp_F']  # Independent variable
Y = merged_data['avg_calc']  # Dependent variable

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     16.04
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):           6.75e-05
# Time:                        20:31:44   Log-Likelihood:                -4357.0
# No. Observations:                 852   AIC:                             8718.
# Df Residuals:                     850   BIC:                             8727.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -285.8680     77.475     -3.690      0.000    -437.932    -133.804
# ...

# %%
X = merged_data['LOWINCPCT']  #Independent 
Y = merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.097
# Method:                 Least Squares   F-statistic:                     92.51
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):           7.39e-21
# Time:                        20:31:46   Log-Likelihood:                -4320.9
# No. Observations:                 852   AIC:                             8646.
# Df Residuals:                     850   BIC:                             8655.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.5102      2.113      4.028      0.000       4.364      12.657
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = merged_data[['LOWINCPCT', 'MeanTemp_F']]  # Include other predictors as well
X = sm.add_constant(X)

vif = pd.DataFrame()
vif['Variable'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#      Variable          VIF
# 0       const  3150.761442
# 1   LOWINCPCT     1.000767
# 2  MeanTemp_F     1.000767

# %%
sns.scatterplot(data=merged_data, x='MeanTemp_F', y='avg_calc', color = 'grey')
sns.regplot(data=merged_data, x='MeanTemp_F', y='avg_calc', ci=None, color = 'grey', line_kws={"color": "black"})
plt.title("Scatterplot with Regression Line")
plt.xlabel("Mean Temperature (°F)")
plt.ylabel("Heat-Related Illness")
plt.show()

# %%
print(merged_data['avg_calc'])
# Out:
# 0       2.327835
# 1       2.327835
# 2       2.327835
# 3       2.327835
# 4       2.327835
#          ...
# 847    10.938010
# 848    10.938010
# 849    10.938010
# 850    10.938010
# 851    10.938010
# Name: avg_calc, Length: 852, dtype: float64

# %%
merged_data['log_avg_calc'] = np.log1p(merged_data['avg_calc'])  # Log(1 + avg_calc)

X = sm.add_constant(merged_data['MeanTemp_F'])
Y = merged_data['log_avg_calc']
model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           log_avg_calc   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     11.44
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):           0.000753
# Time:                        19:28:31   Log-Likelihood:                -1535.1
# No. Observations:                 852   AIC:                             3074.
# Df Residuals:                     850   BIC:                             3084.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -7.5968      2.823     -2.691      0.007     -13.138      -2.055
# ...

# %%
census_summary_data = pd.read_csv('Downloads/HeatWatchGISMasterTable_summary.csv')
census_summary_data.head()
# Out:
#                          CNTY_NAME    ACSTOTPOP      Total m2  PEOPCOLORPCT  \
# 0      Abingdon, Washington County  1565.636364  1.896466e+06      0.069545
# 1                 Arlington County  1161.399015  3.330317e+05      0.374342
# 2  Farmville, Prince Edward County  1286.285714  2.011353e+06      0.368991
# 3                Harrisonburg City  1577.636364  1.364899e+06      0.380234
# 4                   Lynchburg City  1361.603448  2.206348e+06      0.389250
#
#    LOWINCPCT  UNEMPPCT  LINGISOPCT  LESSHSPCT  LIFEEXPPCT  Pct_Trees  \
# 0   0.276052  0.061273    0.003262   0.103888    0.220606   0.280660
# 1   0.128204  0.027433    0.041923   0.045027    0.125659   0.178538
# 2   0.440504  0.035315    0.000000   0.206190    0.105055   0.468038
# 3   0.467765  0.054501    0.076186   0.165810    0.141228   0.119483
# 4   0.360718  0.062634    0.008648   0.092654    0.181998   0.542752
#
#    PCT_ImpSurf  MeanTemp_F   zMeanTemp_F
# 0     0.222115   84.360711  0.000000e+00
# ...

# %%
small_merged_data = census_summary_data.merge(county_data, on="CNTY_NAME", how="inner")

# %%
small_merged_data.head()
# Out:
#                          CNTY_NAME    ACSTOTPOP      Total m2  PEOPCOLORPCT  \
# 0      Abingdon, Washington County  1565.636364  1.896466e+06      0.069545
# 1                 Arlington County  1161.399015  3.330317e+05      0.374342
# 2  Farmville, Prince Edward County  1286.285714  2.011353e+06      0.368991
# 3                Harrisonburg City  1577.636364  1.364899e+06      0.380234
# 4                   Lynchburg City  1361.603448  2.206348e+06      0.389250
#
#    LOWINCPCT  UNEMPPCT  LINGISOPCT  LESSHSPCT  LIFEEXPPCT  Pct_Trees  \
# 0   0.276052  0.061273    0.003262   0.103888    0.220606   0.280660
# 1   0.128204  0.027433    0.041923   0.045027    0.125659   0.178538
# 2   0.440504  0.035315    0.000000   0.206190    0.105055   0.468038
# 3   0.467765  0.054501    0.076186   0.165810    0.141228   0.119483
# 4   0.360718  0.062634    0.008648   0.092654    0.181998   0.542752
#
#    PCT_ImpSurf  MeanTemp_F   zMeanTemp_F  2017 calc  2018 calc  2019 calc  \
# ...

# %%
X = small_merged_data['MeanTemp_F']  #Independent 
Y = small_merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                 -0.066
# Method:                 Least Squares   F-statistic:                    0.4392
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):              0.526
# Time:                        20:13:59   Log-Likelihood:                -47.646
# No. Observations:                  10   AIC:                             99.29
# Df Residuals:                       8   BIC:                             99.90
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -249.9278    396.893     -0.630      0.546   -1165.164     665.308
# ...

# %%
X = small_merged_data['LOWINCPCT']  #Independent 
Y = small_merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.087
# Method:                 Least Squares   F-statistic:                    0.2824
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):              0.610
# Time:                        20:18:13   Log-Likelihood:                -47.739
# No. Observations:                  10   AIC:                             99.48
# Df Residuals:                       8   BIC:                             100.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.3263     32.388     -0.103      0.921     -78.013      71.360
# ...

# %%
X = small_merged_data['UNEMPPCT']  #Independent 
Y = small_merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.114
# Method:                 Least Squares   F-statistic:                   0.08186
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):              0.782
# Time:                        20:18:34   Log-Likelihood:                -47.862
# No. Observations:                  10   AIC:                             99.72
# Df Residuals:                       8   BIC:                             100.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.8259     23.958      0.285      0.783     -48.421      62.072
# ...

# %%
X = small_merged_data['LIFEEXPPCT']  #Independent 
Y = small_merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.119
# Method:                 Least Squares   F-statistic:                   0.04511
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):              0.837
# Time:                        20:18:54   Log-Likelihood:                -47.885
# No. Observations:                  10   AIC:                             99.77
# Df Residuals:                       8   BIC:                             100.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.0274     43.574      0.092      0.929     -96.454     104.509
# ...

# %%
X = small_merged_data['Pct_Trees']  #Independent 
Y = small_merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Pct_Trees   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.117
# Method:                 Least Squares   F-statistic:                   0.05560
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):              0.820
# Time:                        20:19:05   Log-Likelihood:                 5.9231
# No. Observations:                  10   AIC:                            -7.846
# Df Residuals:                       8   BIC:                            -7.241
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3097      0.201      1.544      0.161      -0.153       0.772
# ...

# %%
X = small_merged_data['PCT_ImpSurf']  #Independent 
Y = small_merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.8224
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):              0.391
# Time:                        20:20:00   Log-Likelihood:                -47.424
# No. Observations:                  10   AIC:                             98.85
# Df Residuals:                       8   BIC:                             99.45
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -15.5705     33.019     -0.472      0.650     -91.713      60.572
# ...

# %%
X = merged_data['PCT_ImpSurf']  #Independent 
Y = merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     6.242
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):             0.0127
# Time:                        20:21:09   Log-Likelihood:                -4361.8
# No. Observations:                 852   AIC:                             8728.
# Df Residuals:                     850   BIC:                             8737.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          15.4678      3.817      4.053      0.000       7.977      22.959
# ...

# %%
X = merged_data['Pct_Trees']  #Independent 
Y = merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9557
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):              0.329
# Time:                        20:22:01   Log-Likelihood:                -4364.5
# No. Observations:                 852   AIC:                             8733.
# Df Residuals:                     850   BIC:                             8742.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         26.1681      2.323     11.264      0.000      21.608      30.728
# ...

# %%
X = merged_data['PEOPCOLORPCT']  #Independent 
Y = merged_data['avg_calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               avg_calc   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     68.99
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):           3.89e-16
# Time:                        20:26:02   Log-Likelihood:                -4331.7
# No. Observations:                 852   AIC:                             8667.
# Df Residuals:                     850   BIC:                             8677.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            6.5899      2.523      2.611      0.009       1.637      11.543
# ...

# %%
socio_data = pd.read_csv('Downloads/Census2017_csv.csv')
socio_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 socio_data = pd.read_csv('Downloads/Census2017_csv.csv')
#       2 socio_data.head()
#
# NameError: name 'pd' is not defined

# %%
HRI_Data = pd.read_csv('Downloads/HRI_Data (2).csv')
HRI_Data.head()
# Out:
#          Area  2017  2018  2019  2020  2021 2017sum 2018sum 2019sum 2020sum  \
# 0    Accomack   2.0   2.0  13.0  18.0  26.0   32685   32581   32316   33392
# 1   Albemarle  42.0  45.0  47.0  17.0  29.0  155231  108377  109330  112510
# 2  Alexandria  13.0  15.0  21.0  11.0  16.0  159215  159069  159428  159139
# 3   Alleghany   6.0  10.0   8.0  15.0   7.0   20704    5578    5538    5745
# 4      Amelia   2.0   2.0   8.0   5.0   2.0   12980   13057   13145   13267
#
#   2021sum  2017calc   2018calc   2019calc   2020calc   2021calc
# 0   33410  0.611901   0.613855   4.022775   5.390513   7.782101
# 1  113882  2.705645   4.152173   4.298912   1.510977   2.546495
# 2  155105  0.816506   0.942987   1.317209   0.691220   1.031559
# 3    5716  2.897991  17.927573  14.445648  26.109661  12.246326
# 4   13306  1.540832   1.531745   6.085964   3.768750   1.503081

# %%
merged_county = socio_data.merge(HRI_Data, on="Area", how="inner")
merged_county.head()
# Out:
#          Area  Medianincome(2017)45to64years_2017  \
# 0    Accomack                             50677.0
# 1   Albemarle                             80915.0
# 2  Alexandria                            102974.0
# 3   Alleghany                             51721.0
# 4      Amelia                             69659.0
#
#    Medianincome(2017)65yearsandover  Medianincome(2017)Families  \
# 0                           35488.0                     53152.0
# 1                           57011.0                     88436.0
# 2                           77860.0                    119485.0
# 3                           33066.0                     57892.0
# 4                           47361.0                     69614.0
#
#    Number(2017)45to64years  Number(2017)65yearsandover  Number(2017)Families  \
# 0                   5661.0                      4505.0                8955.0
# 1                  20870.0                     13906.0               33927.0
# ...

# %%
print("Columns in socio_data:", len(socio_data.columns))
print("Columns in HRI_Data:", len(HRI_Data.columns))
# Out:
# Columns in socio_data: 55
# Columns in HRI_Data: 16

# %%
print("Common columns across datasets:")
print(set(socio_data.columns) & set(HRI_Data.columns))
# Out:
# Common columns across datasets:
# {'Area'}

# %%
print(merged_county.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 70 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Area                                107 non-null    object
#  1   Medianincome(2017)45to64years_2017  107 non-null    float64
#  2   Medianincome(2017)65yearsandover    107 non-null    float64
#  3   Medianincome(2017)Families          107 non-null    float64
#  4   Number(2017)45to64years             107 non-null    float64
#  5   Number(2017)65yearsandover          107 non-null    float64
#  6   Number(2017)Families                107 non-null    float64
#  7   Median(2018)Households              107 non-null    float64
#  8   Median(2018)White                   107 non-null    float64
#  9   Median(2018)BlackorAfricanAmerican  107 non-null    float64
#  10  Median(2018)45to64years             107 non-null    float64
# ...

# %%
X = merged_county['Median(2019)45to64years']  #Independent 
Y = merged_county['2019calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 X = merged_county['Median(2019)45to64years']  #Independent
#       2 Y = merged_county['2019calc']  #Dependent
#       4 X = sm.add_constant(X)
#
# NameError: name 'merged_county' is not defined

# %%
X = merged_county['Medianincome(2017)45to64years_2017']  #Independent 
Y = merged_county['2017calc']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               2017calc   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                  0.005065
# Date:                Tue, 28 Jan 2025   Prob (F-statistic):              0.943
# Time:                        07:33:14   Log-Likelihood:                -185.44
# No. Observations:                 107   AIC:                             374.9
# Df Residuals:                     105   BIC:                             380.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
merged_county['log_Median(2019)45to64years'] = np.log1p(merged_county['Median(2019)45to64years'])
merged_county['log_2019calc'] = np.log1p(merged_county['2019calc'])

# Run OLS regression on transformed variables
X = sm.add_constant(merged_county['log_Median(2019)45to64years'])
Y = merged_county['log_2019calc']
model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           log_2019calc   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.421
# Date:                Mon, 27 Jan 2025   Prob (F-statistic):              0.236
# Time:                        14:34:16   Log-Likelihood:                -107.75
# No. Observations:                 107   AIC:                             219.5
# Df Residuals:                     105   BIC:                             224.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           4.0803      2.150      1.898      0.060      -0.183       8.344
# ...

# %%
print(X.describe())
print(Y.describe())
# Out:
#        const  log_Median(2019)45to64years
# count  107.0                   107.000000
# mean     1.0                    11.158635
# std      0.0                     0.337205
# min      1.0                    10.249273
# 25%      1.0                    10.932793
# 50%      1.0                    11.118013
# 75%      1.0                    11.391333
# max      1.0                    12.017071
# count    107.000000
# mean       1.518217
# std        0.669982
# min        0.000000
# 25%        1.070413
# 50%        1.512635
# 75%        1.837763
# max        3.655296
# Name: log_2019calc, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(model.fittedvalues, model.resid, color = 'grey')
plt.axhline(0, color='grey', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
X = merged_county.select_dtypes(include=['number'])

# %%
import seaborn as sns
sns.heatmap(X.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr = X.corr()
target_corr = corr['2019calc'].sort_values(ascending=False)
print(target_corr)
# Out:
# 2019calc                       1.000000
# 2021calc                       0.908121
# log_2019calc                   0.859721
# 2018calc                       0.855410
# 2020calc                       0.810677
#                                  ...
# Median(2019)White             -0.227985
# Median(2019)Households        -0.228239
# Median(2019)65yearsandover    -0.230333
# Median(2019)Families          -0.238052
# log_Median(2019)45to64years   -0.243423
# Name: 2019calc, Length: 66, dtype: float64

# %%
corr_table = X.corr()

rename_dict = {
    "2019calc": "HRI Rates",
    "Median(2019)45to64years": "Median Income (45-64)",
    "Pct_Trees": "Tree Cover Percentage",
    "PCT_Impsurf": "Impervious Surface Percentage"
}

corr_table.rename(columns=rename_dict, index=rename_dict, inplace=True)

print(corr_table)
# Out:
#                        const  Median Income (45-64)
# const                    NaN                    NaN
# Median Income (45-64)    NaN                    1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_corr_vars = target_corr.index[:10]  # Top 10 variables

sns.heatmap(X[top_corr_vars].corr(), annot=True, cmap="coolwarm")
plt.title("Heatmap of Top Correlated Variables")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(merged_county['Median(2019)45to64years'], merged_county['2019calc'], color = 'grey')
plt.xlabel('Median Income (2019) 45-64 Years')
plt.ylabel('Heat-Related Illness Rates')
plt.title('Scatter Plot: Median Income vs Heat-Related Illness Rates')
plt.axhline(merged_county['2019calc'].mean(), color='black', linestyle='--', label='Mean 2019calc')
plt.legend()
plt.show()

# %%
x = merged_county['Median(2019)45to64years']
y = merged_county['2019calc']
slope, intercept, r_value, p_value, std_err = linregress(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from scipy.stats import linregress
# ----> 3 x = merged_county['Median(2019)45to64years']
#       4 y = merged_county['2019calc']
#       5 slope, intercept, r_value, p_value, std_err = linregress(x, y)
#
# NameError: name 'merged_county' is not defined

# %%
sns.regplot(x='Median(2019)45to64years', y='2019calc', data=merged_county, color = 'grey', scatter_kws={'alpha':0.5}, line_kws={'color':'black'})
plt.xlabel('Median Income (2019) 45-64 Years')
plt.ylabel('Heat-Related Illness Rates')
plt.title('Trendline: Median Income vs Heat-Related Illness Rates')
plt.show()

# %%
healthcare_data = pd.read_csv('Downloads/20-21Emergency.csv')
healthcare_data.head()
# Out:
#                Area  M.D., Emergency Medicine (County Level File)  \
# 0   Accomack County                                             1
# 1  Albemarle County                                            38
# 2   Alexandria City                                            32
# 3  Alleghany County                                             0
# 4     Amelia County                                             0
#
#    Population, All (County Level File)  Rate (per 100,000 population)  Source
# 0                                32238                           3.10     NaN
# 1                               110652                          34.34     NaN
# 2                               158726                          20.16     NaN
# 3                                14701                           0.00     NaN
# 4                                13014                           0.00     NaN

# %%
healthcare_data = healthcare_data.drop(columns=["Source"])

# %%
healthcare_data.head()
# Out:
#                Area  M.D., Emergency Medicine (County Level File)  \
# 0   Accomack County                                             1
# 1  Albemarle County                                            38
# 2   Alexandria City                                            32
# 3  Alleghany County                                             0
# 4     Amelia County                                             0
#
#    Population, All (County Level File)  Rate (per 100,000 population)
# 0                                32238                           3.10
# 1                               110652                          34.34
# 2                               158726                          20.16
# 3                                14701                           0.00
# 4                                13014                           0.00

# %%
socio_medical = pd.read_csv('Downloads/socio_medical_21.csv')
socio_medical.head()
# Out:
#                Area  Median income(dollars)Households  \
# 0   Accomack County                           50601.0
# 1  Albemarle County                           90568.0
# 2   Alexandria city                           49705.0
# 3  Alleghany County                           57420.0
# 4     Amelia County                           60876.0
#
#    Median income(dollars)25 to 44 years  Median income(dollars)45 to 64 years  \
# 0                               56712.0                               59356.0
# 1                               95992.0                              113342.0
# 2                               63333.0                               59500.0
# 3                               65871.0                               69798.0
# 4                               69679.0                               74401.0
#
#    Median income(dollars)65 years and over  Median income(dollars)Families  \
# 0                                  42225.0                         63763.0
# ...

# %%
merged_medical = healthcare_data.merge(socio_medical, on="Area", how="inner")

# %%
merged_medical.head()
# Out:
#                Area  M.D., Emergency Medicine (County Level File)  \
# 0   Accomack County                                             1
# 1  Albemarle County                                            38
# 2  Alleghany County                                             0
# 3     Amelia County                                             0
# 4    Amherst County                                             0
#
#    Population, All (County Level File)  Rate (per 100,000 population)  \
# 0                                32238                           3.10
# 1                               110652                          34.34
# 2                                14701                           0.00
# 3                                13014                           0.00
# 4                                31667                           0.00
#
#    Median income(dollars)Households  Median income(dollars)25 to 44 years  \
# ...

# %%
print(merged_medical.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Area                                          95 non-null     object
#  1   M.D., Emergency Medicine (County Level File)  95 non-null     int64
#  2   Population, All (County Level File)           95 non-null     int64
#  3   Rate (per 100,000 population)                 95 non-null     float64
#  4   Median income(dollars)Households              95 non-null     float64
#  5   Median income(dollars)25 to 44 years          95 non-null     float64
#  6   Median income(dollars)45 to 64 years          95 non-null     float64
#  7   Median income(dollars)65 years and over       95 non-null     float64
#  8   Median income(dollars)Families                95 non-null     float64
# ...

# %%
X = merged_medical['Median income(dollars)45 to 64 years']  #Independent 
Y = merged_medical['Rate (per 100,000 population)']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                                   OLS Regression Results
# ...
# Dep. Variable:     Rate (per 100,000 population)   R-squared:                       0.005
# Model:                                       OLS   Adj. R-squared:                 -0.006
# Method:                            Least Squares   F-statistic:                    0.4628
# Date:                           Mon, 27 Jan 2025   Prob (F-statistic):              0.498
# Time:                                   07:51:44   Log-Likelihood:                -321.47
# No. Observations:                             95   AIC:                             646.9
# Df Residuals:                                 93   BIC:                             652.0
# Df Model:                                      1
# Covariance Type:                       nonrobust
# ...
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
X = merged_medical['Median income(dollars)65 years and over']  #Independent 
Y = merged_medical['Rate (per 100,000 population)']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                                   OLS Regression Results
# ...
# Dep. Variable:     Rate (per 100,000 population)   R-squared:                       0.006
# Model:                                       OLS   Adj. R-squared:                 -0.005
# Method:                            Least Squares   F-statistic:                    0.5154
# Date:                           Mon, 27 Jan 2025   Prob (F-statistic):              0.475
# Time:                                   07:53:52   Log-Likelihood:                -321.44
# No. Observations:                             95   AIC:                             646.9
# Df Residuals:                                 93   BIC:                             652.0
# Df Model:                                      1
# Covariance Type:                       nonrobust
# ...
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
X = merged_medical['Median income(dollars)Households']  #Independent 
Y = merged_medical['Rate (per 100,000 population)']  #Dependent

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                                   OLS Regression Results
# ...
# Dep. Variable:     Rate (per 100,000 population)   R-squared:                       0.011
# Model:                                       OLS   Adj. R-squared:                  0.001
# Method:                            Least Squares   F-statistic:                     1.053
# Date:                           Mon, 27 Jan 2025   Prob (F-statistic):              0.307
# Time:                                   07:57:00   Log-Likelihood:                -321.17
# No. Observations:                             95   AIC:                             646.3
# Df Residuals:                                 93   BIC:                             651.4
# Df Model:                                      1
# Covariance Type:                       nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Scatter plot with trendline (Medical Access)
sns.regplot(x='Median income(dollars)Households', y='Rate (per 100,000 population)', data=merged_medical, color = 'grey', scatter_kws={'alpha':0.5}, line_kws={'color':'black'})
plt.xlabel('Median income(dollars)')
plt.ylabel('Medical Access')
plt.title('Trendline: Median Income vs Medical Access')
plt.show()

# %%
merged_county.head()
# Out:
#          Area  Medianincome(2017)45to64years_2017  \
# 0    Accomack                             50677.0
# 1   Albemarle                             80915.0
# 2  Alexandria                            102974.0
# 3   Alleghany                             51721.0
# 4      Amelia                             69659.0
#
#    Medianincome(2017)65yearsandover  Medianincome(2017)Families  \
# 0                           35488.0                     53152.0
# 1                           57011.0                     88436.0
# 2                           77860.0                    119485.0
# 3                           33066.0                     57892.0
# 4                           47361.0                     69614.0
#
#    Number(2017)45to64years  Number(2017)65yearsandover  Number(2017)Families  \
# 0                   5661.0                      4505.0                8955.0
# 1                  20870.0                     13906.0               33927.0
# ...

# %%
formula = "HRI_rate ~ Median + tree_cover + impervious_surface"
glm = smf.glm(formula=formula, data=merged_county, family=sm.families.Gaussian())
glm_result = glm.fit()

print(glm_result.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/compat.py:40, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39 try:
# ---> 40     return f(*args, **kwargs)
#      41 except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/patsy/eval.py:179, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     178 code = compile(expr, source_name, "eval", self.flags, False)
# --> 179 return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#
# File <string>:1
#
# NameError: name 'impervious_surface' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[663], line 2
#       1 formula = "HRI_rate ~ Median + tree_cover + impervious_surface"
# ...
